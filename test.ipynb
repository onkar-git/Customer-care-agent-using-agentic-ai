# %%
import os

# %%
# %pwd
# Out:
# 'd:\\jio\\bedrocl\\Customer-care-agent-using-agentic-ai'

# %%
from langchain.document_loaders import PyPDFDirectoryLoader

# %%
def get_documents():
    loader = PyPDFDirectoryLoader("pdf-data")  # Ensure PDF files are in 'pdf-data' folder
    documents = loader.load()
    print(documents)
    # ✅ Add proper metadata (document source names)
    for doc in documents:
        
        doc.metadata["source"] = doc.metadata.get("source", "Unknown Document")

# %%
data = get_documents()
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2025-03-04T17:09:12+05:30', 'author': 'Admin', 'moddate': '2025-03-04T17:09:12+05:30', 'source': 'pdf-data\\jiopayFAQs.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}, page_content='Question: What is JioPay Business? \nAnswer:  jioPay Business is a payment aggregator and gateway provided by Jio  Payment Solutions Limited \n(formerly known as Reliance Payment Solutions Limited), a subsidiary of Reliance Industries Limited. It offers \nmerchants and businesses of all sizes simple and self -service products to accept and process payments online \nand offline from their customers. JioPay Business supports payments through web, mobile, and Point of Sale \n(POS) systems, making it convenient for merchants to manage transactions. With JioPay Business, businesses \ncan streamline their payment operations and provide a seamless payment experience to their customers. \nQuestion: W
# ...

# %%
D:\jio\bedrocl\questions.json
